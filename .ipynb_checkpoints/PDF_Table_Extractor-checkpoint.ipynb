# %% [markdown]
# # Building Table Extractor using Python
# - Here I am going to use World Economic Situation and prospects 2020
# * the link to file from google search ;)

# %%
# installing camelot-py should be done from terminal ONLY using the next 2 lines of code
# first -->  pip3 install camelot-py
# then pip install "camelot-py[base]"

# %%
# importing packages
import pandas as pd
import camelot as cm
import seaborn as sns
import numpy as np

# %%
# getting the file link and choose arguments as stream and the pages i needed
input_pdf = cm.read_pdf("https://www.un.org/development/desa/dpad/wp-content/uploads/sites/45/WESP2020_FullReport.pdf", \
                       flavor= 'stream',pages='24,25') # use this for pdfs from online sources

# %% [markdown]
# ## some columns names ends with letters and it is as follow
# - a. Partly estimated.
# - b. Forecast.
# - c. Calendar year basis.
# ----

# %% [markdown]
# - "stream", "lattice" # those are the reading methods used by camelot and in this example \
# - I used lattice as a flavor but gave me an error that I need to install GhostScript so
# - I changed to stream as a flavor and it worked fine 'going to check what is the difference later'

# %% [markdown]
# ### input_pdf = cm.read_pdf("your path here", flavor='lattice', pages='1,2') # for local pdfs

# %%
input_pdf # confirmation for data and it will give back the number of tables created as N
# Out:
# <TableList n=2>

# %%
# getting the shape of each extracted table
for n in input_pdf:
    print(n)
# Out:
# <Table shape=(40, 8)>
# <Table shape=(37, 6)>

# %%
# checking the first table with index zero
input_pdf[0].df
# Out:
#                                                     0     1     2      3  \
# 0   Growth of world output and gross domestic product
# 1
# 2                            Annual percentage change  2017  2018  2019a
# 3                                               World   3.2   3.0    2.3
# 4                                 Developed economies   2.4   2.2    1.7
# 5                            United States of America   2.4   2.9    2.2
# 6                                               Japan   1.9   0.8    0.7
# 7                                      European Union   2.6   2.0    1.4
# 8                                               EU-15   2.4   1.8    1.2
# 9                                               EU-13   4.8   4.3    3.8
# 10                                          Euro area   2.5   1.9    1.2
# 11                          Other developed countries   2.6   2.3    1.7
# 12                            Economies in transition   2.2   2.7    1.9
# 13                               South-Eastern Europe   2.5   3.9    3.1
# 14                 Commonwealth of Independent States   2.1   2.7    1.8
# 15                                        and Georgia
# 16                                 Russian Federation   1.6   2.3    1.1
# 17                               Developing economies   4.5   4.2    3.4
# 18                                             Africa   2.9   2.7    2.9
# 19                                       North Africa   4.0   2.6    3.4
# 20                                        East Africa   5.4   6.3    6.0
# 21                                     Central Africa   0.3   1.6    2.7
# 22                                        West Africa   2.7   3.3    3.5
# 23                                    Southern Africa   1.1   0.9    0.3
# 24                                East and South Asia   6.1   5.7    4.8
# 25                                          East Asia   5.9   5.7    5.2
# 26                                              China   6.8   6.6    6.1
# 27                                         South Asia   6.8   5.6    3.3
# 28                                             Indiac   7.2   6.8    5.7
# 29                                       Western Asia   2.6   2.3    1.0
# 30                    Latin America and the Caribbean   1.2   0.9    0.1
# 31                                      South America   0.7   0.4   -0.1
# 32                                             Brazil   1.3   1.1    1.0
# 33                         Mexico and Central America   2.4   2.3    0.5
# 34                                          Caribbean  -0.2   1.6    1.2
# 35                          Least developed countries   4.5   4.6    4.9
# 36                                   Memorandum items
# 37                                       World traded   5.7   3.9    0.3
# 38              World output growth with PPP weightse   3.8   3.6    2.9
# 39                                   Source: UN DESA.
#
#         4      5     6                      7
# 0
# 1                       Change from WESP 2019
# 2   2020b  2021b  2019                   2020
# 3     2.5    2.7  -0.7                   -0.5
# 4     1.5    1.7  -0.4                   -0.4
# 5     1.7    1.8  -0.3                   -0.3
# 6     0.9    1.3  -0.7                   -0.3
# 7     1.6    1.7  -0.6                   -0.4
# 8     1.4    1.6  -0.6                   -0.4
# 9     3.3    3.2   0.2                   -0.2
# 10    1.4    1.5  -0.7                   -0.5
# 11    1.8    1.9  -0.5                   -0.4
# 12    2.3    2.5  -0.2                   -0.3
# 13    3.4    3.4  -0.6                   -0.3
# 14    2.3    2.4  -0.2                   -0.3
# 15
# 16    1.8    2.0  -0.3                   -0.3
# 17    4.0    4.3  -0.9                   -0.6
# 18    3.2    3.5  -0.5                   -0.5
# 19    3.6    3.7   0.0                    0.0
# 20    6.0    6.2  -0.3                   -0.5
# 21    2.9    3.1   0.1                   -0.9
# 22    3.6    3.8   0.0                   -0.2
# 23    0.9    1.9  -1.8                   -1.7
# 24    5.2    5.2  -0.7                   -0.4
# 25    5.2    5.2  -0.3                   -0.2
# 26    6.0    5.9  -0.2                   -0.2
# 27    5.1    5.3  -2.4                   -1.0
# 28    6.6    6.3  -1.9                   -0.8
# 29    2.4    2.8  -1.3                   -1.0
# 30    1.3    2.0  -1.6                   -1.0
# 31    1.1    2.0  -1.4                   -1.2
# 32    1.7    2.3  -1.1                   -0.8
# 33    1.6    1.9  -2.0                   -0.7
# 34    5.7    3.4  -0.8                    3.7
# 35    5.1    5.4  -0.1                   -0.6
# 36
# 37    2.3    3.2  -3.4                   -1.6
# 38    3.2    3.4  -0.7                   -0.5
# 39

# %% [markdown]
# ### "Growth of world output and gross domestic product" is the title of the first table on the site

# %%
# assigning the result to a DataFrame --> df
df = input_pdf[0].df.loc[2:38, :]

# %% [markdown]
# ## to convert df to csv use
# - df.to_csv("output file name")
# ## to convert to excel use
# - df.to_excel("output file name")

# %%
# getting a copy of the DataFrame to do operations on it, so when i need to revert back i just run the previous cell
wesp_2020 = df.copy()

# %%
# making the first row is the columns names
wesp_2020.columns = wesp_2020.iloc[0]
#reseting the index of the dataframe
wesp_2020.reset_index(drop=True)
# dropping the first row as it is now columns and has no meanning in the dataframe
wesp_2020 = wesp_2020.iloc[1:,:]
wesp_2020
# Out:
# 2                Annual percentage change  2017 2018 2019a 2020b 2021b  2019  \
# 3                                   World   3.2  3.0   2.3   2.5   2.7  -0.7
# 4                     Developed economies   2.4  2.2   1.7   1.5   1.7  -0.4
# 5                United States of America   2.4  2.9   2.2   1.7   1.8  -0.3
# 6                                   Japan   1.9  0.8   0.7   0.9   1.3  -0.7
# 7                          European Union   2.6  2.0   1.4   1.6   1.7  -0.6
# 8                                   EU-15   2.4  1.8   1.2   1.4   1.6  -0.6
# 9                                   EU-13   4.8  4.3   3.8   3.3   3.2   0.2
# 10                              Euro area   2.5  1.9   1.2   1.4   1.5  -0.7
# 11              Other developed countries   2.6  2.3   1.7   1.8   1.9  -0.5
# 12                Economies in transition   2.2  2.7   1.9   2.3   2.5  -0.2
# 13                   South-Eastern Europe   2.5  3.9   3.1   3.4   3.4  -0.6
# 14     Commonwealth of Independent States   2.1  2.7   1.8   2.3   2.4  -0.2
# 15                            and Georgia
# 16                     Russian Federation   1.6  2.3   1.1   1.8   2.0  -0.3
# 17                   Developing economies   4.5  4.2   3.4   4.0   4.3  -0.9
# 18                                 Africa   2.9  2.7   2.9   3.2   3.5  -0.5
# 19                           North Africa   4.0  2.6   3.4   3.6   3.7   0.0
# 20                            East Africa   5.4  6.3   6.0   6.0   6.2  -0.3
# 21                         Central Africa   0.3  1.6   2.7   2.9   3.1   0.1
# 22                            West Africa   2.7  3.3   3.5   3.6   3.8   0.0
# 23                        Southern Africa   1.1  0.9   0.3   0.9   1.9  -1.8
# 24                    East and South Asia   6.1  5.7   4.8   5.2   5.2  -0.7
# 25                              East Asia   5.9  5.7   5.2   5.2   5.2  -0.3
# 26                                  China   6.8  6.6   6.1   6.0   5.9  -0.2
# 27                             South Asia   6.8  5.6   3.3   5.1   5.3  -2.4
# 28                                 Indiac   7.2  6.8   5.7   6.6   6.3  -1.9
# 29                           Western Asia   2.6  2.3   1.0   2.4   2.8  -1.3
# 30        Latin America and the Caribbean   1.2  0.9   0.1   1.3   2.0  -1.6
# 31                          South America   0.7  0.4  -0.1   1.1   2.0  -1.4
# 32                                 Brazil   1.3  1.1   1.0   1.7   2.3  -1.1
# 33             Mexico and Central America   2.4  2.3   0.5   1.6   1.9  -2.0
# 34                              Caribbean  -0.2  1.6   1.2   5.7   3.4  -0.8
# 35              Least developed countries   4.5  4.6   4.9   5.1   5.4  -0.1
# 36                       Memorandum items
# 37                           World traded   5.7  3.9   0.3   2.3   3.2  -3.4
# 38  World output growth with PPP weightse   3.8  3.6   2.9   3.2   3.4  -0.7
#
# 2   2020
# 3   -0.5
# 4   -0.4
# 5   -0.3
# 6   -0.3
# 7   -0.4
# 8   -0.4
# 9   -0.2
# 10  -0.5
# 11  -0.4
# 12  -0.3
# 13  -0.3
# 14  -0.3
# 15
# 16  -0.3
# 17  -0.6
# 18  -0.5
# 19   0.0
# 20  -0.5
# 21  -0.9
# 22  -0.2
# 23  -1.7
# 24  -0.4
# 25  -0.2
# 26  -0.2
# 27  -1.0
# 28  -0.8
# 29  -1.0
# 30  -1.0
# 31  -1.2
# 32  -0.8
# 33  -0.7
# 34   3.7
# 35  -0.6
# 36
# 37  -1.6
# 38  -0.5

# %%
# getting the second dataframe from the second table
input_pdf[1].df
# Out:
#                                                     0     1     2      3  \
# 0   Growth of world output and gross domestic prod...
# 1                            Annual percentage change
# 2                                                      2017  2018  2019a
# 3                                               World   2.1   1.9    1.2
# 4                                 Developed economies   2.1   1.9    1.3
# 5                            United States of America   1.7   2.3    1.6
# 6                                               Japan   2.1   1.0    1.0
# 7                                      European Union   2.4   1.8    1.3
# 8                                               EU-15   2.0   1.5    0.9
# 9                                               EU-13   5.1   4.6    4.1
# 10                                          Euro area   2.3   1.7    1.0
# 11                          Other developed countries   1.5   1.2    0.7
# 12                            Economies in transition   1.7   2.4    1.5
# 13                               South-Eastern Europe   2.8   4.2    3.4
# 14                 Commonwealth of Independent States
# 15                                        and Georgia   1.7   2.3    1.4
# 16                                 Russian Federation   1.5   2.1    1.0
# 17                               Developing economies   3.2   2.9    2.1
# 18                                             Africa   0.3   0.1    0.4
# 19                                       North Africa   2.0   0.6    1.5
# 20                                        East Africa   2.5   3.3    3.1
# 21                                     Central Africa  -2.3  -1.1    0.0
# 22                                        West Africa   0.0   0.6    0.8
# 23                                    Southern Africa  -1.2  -1.4   -1.9
# 24                                East and South Asia   5.1   4.8    3.9
# 25                                          East Asia   5.2   5.1    4.6
# 26                                              China   6.3   6.1    5.7
# 27                                         South Asia   5.6   4.4    2.1
# 28                                             Indiac   6.3   5.8    4.3
# 29                                       Western Asia   0.8   0.6   -0.7
# 30                    Latin America and the Caribbean   0.2   0.0   -0.8
# 31                                      South America  -0.1  -0.5   -1.0
# 32                                             Brazil   0.5   0.3    0.2
# 33                         Mexico and Central America   1.2   1.1   -0.6
# 34                                          Caribbean  -0.8   1.0    0.6
# 35                          Least developed countries   2.1   2.2    2.5
# 36                                   Source: UN DESA.
#
#         4      5
# 0
# 1
# 2   2020b  2021b
# 3     1.5    1.7
# 4     1.3    1.4
# 5     1.1    1.2
# 6     1.2    1.6
# 7     1.5    1.6
# 8     1.2    1.4
# 9     3.6    3.5
# 10    1.3    1.5
# 11    0.9    1.0
# 12    2.0    2.2
# 13    3.7    3.8
# 14
# 15    1.9    2.1
# 16    1.7    2.0
# 17    2.8    3.1
# 18    0.7    1.1
# 19    1.7    1.8
# 20    3.2    3.4
# 21    0.2    0.4
# 22    0.9    1.1
# 23   -1.3   -0.3
# 24    4.3    4.4
# 25    4.6    4.6
# 26    5.6    5.5
# 27    3.9    4.1
# 28    5.6    5.4
# 29    0.7    1.2
# 30    0.4    1.1
# 31    0.3    1.2
# 32    0.9    1.6
# 33    0.5    0.8
# 34    5.1    2.8
# 35    2.7    3.0
# 36

# %%
# loading the second table into DataFrame
df2 = input_pdf[1].df.loc[2:36, :]

# %% [markdown]
# ## "Growth of world output and gross domestic prod..." was the title of the second table in the pdf

# %%
# getting a copy of the second DataFrame df2
gwog_2020 = df2.copy()

# %%
# making the first row is the columns names 
gwog_2020.columns = gwog_2020.iloc[0]
# reseting the index of the dataframe to be able to drop the duplicated first row 
gwog_2020.reset_index(drop=True)
# dropping the first raw as it has no meaning in dataframe now
gwog_2020 = gwog_2020.iloc[1:,:]
gwog_2020
# Out:
# 2                                       2017  2018 2019a 2020b 2021b
# 3                                World   2.1   1.9   1.2   1.5   1.7
# 4                  Developed economies   2.1   1.9   1.3   1.3   1.4
# 5             United States of America   1.7   2.3   1.6   1.1   1.2
# 6                                Japan   2.1   1.0   1.0   1.2   1.6
# 7                       European Union   2.4   1.8   1.3   1.5   1.6
# 8                                EU-15   2.0   1.5   0.9   1.2   1.4
# 9                                EU-13   5.1   4.6   4.1   3.6   3.5
# 10                           Euro area   2.3   1.7   1.0   1.3   1.5
# 11           Other developed countries   1.5   1.2   0.7   0.9   1.0
# 12             Economies in transition   1.7   2.4   1.5   2.0   2.2
# 13                South-Eastern Europe   2.8   4.2   3.4   3.7   3.8
# 14  Commonwealth of Independent States
# 15                         and Georgia   1.7   2.3   1.4   1.9   2.1
# 16                  Russian Federation   1.5   2.1   1.0   1.7   2.0
# 17                Developing economies   3.2   2.9   2.1   2.8   3.1
# 18                              Africa   0.3   0.1   0.4   0.7   1.1
# 19                        North Africa   2.0   0.6   1.5   1.7   1.8
# 20                         East Africa   2.5   3.3   3.1   3.2   3.4
# 21                      Central Africa  -2.3  -1.1   0.0   0.2   0.4
# 22                         West Africa   0.0   0.6   0.8   0.9   1.1
# 23                     Southern Africa  -1.2  -1.4  -1.9  -1.3  -0.3
# 24                 East and South Asia   5.1   4.8   3.9   4.3   4.4
# 25                           East Asia   5.2   5.1   4.6   4.6   4.6
# 26                               China   6.3   6.1   5.7   5.6   5.5
# 27                          South Asia   5.6   4.4   2.1   3.9   4.1
# 28                              Indiac   6.3   5.8   4.3   5.6   5.4
# 29                        Western Asia   0.8   0.6  -0.7   0.7   1.2
# 30     Latin America and the Caribbean   0.2   0.0  -0.8   0.4   1.1
# 31                       South America  -0.1  -0.5  -1.0   0.3   1.2
# 32                              Brazil   0.5   0.3   0.2   0.9   1.6
# 33          Mexico and Central America   1.2   1.1  -0.6   0.5   0.8
# 34                           Caribbean  -0.8   1.0   0.6   5.1   2.8
# 35           Least developed countries   2.1   2.2   2.5   2.7   3.0
# 36                    Source: UN DESA.

# %%
# reaplacing the empty values with np.nan to drop them
wesp_2020.replace("", np.nan, inplace=True)
wesp_2020.dropna() # drop na values
# Out:
# 2                Annual percentage change  2017 2018 2019a 2020b 2021b  2019  \
# 3                                   World   3.2  3.0   2.3   2.5   2.7  -0.7
# 4                     Developed economies   2.4  2.2   1.7   1.5   1.7  -0.4
# 5                United States of America   2.4  2.9   2.2   1.7   1.8  -0.3
# 6                                   Japan   1.9  0.8   0.7   0.9   1.3  -0.7
# 7                          European Union   2.6  2.0   1.4   1.6   1.7  -0.6
# 8                                   EU-15   2.4  1.8   1.2   1.4   1.6  -0.6
# 9                                   EU-13   4.8  4.3   3.8   3.3   3.2   0.2
# 10                              Euro area   2.5  1.9   1.2   1.4   1.5  -0.7
# 11              Other developed countries   2.6  2.3   1.7   1.8   1.9  -0.5
# 12                Economies in transition   2.2  2.7   1.9   2.3   2.5  -0.2
# 13                   South-Eastern Europe   2.5  3.9   3.1   3.4   3.4  -0.6
# 14     Commonwealth of Independent States   2.1  2.7   1.8   2.3   2.4  -0.2
# 16                     Russian Federation   1.6  2.3   1.1   1.8   2.0  -0.3
# 17                   Developing economies   4.5  4.2   3.4   4.0   4.3  -0.9
# 18                                 Africa   2.9  2.7   2.9   3.2   3.5  -0.5
# 19                           North Africa   4.0  2.6   3.4   3.6   3.7   0.0
# 20                            East Africa   5.4  6.3   6.0   6.0   6.2  -0.3
# 21                         Central Africa   0.3  1.6   2.7   2.9   3.1   0.1
# 22                            West Africa   2.7  3.3   3.5   3.6   3.8   0.0
# 23                        Southern Africa   1.1  0.9   0.3   0.9   1.9  -1.8
# 24                    East and South Asia   6.1  5.7   4.8   5.2   5.2  -0.7
# 25                              East Asia   5.9  5.7   5.2   5.2   5.2  -0.3
# 26                                  China   6.8  6.6   6.1   6.0   5.9  -0.2
# 27                             South Asia   6.8  5.6   3.3   5.1   5.3  -2.4
# 28                                 Indiac   7.2  6.8   5.7   6.6   6.3  -1.9
# 29                           Western Asia   2.6  2.3   1.0   2.4   2.8  -1.3
# 30        Latin America and the Caribbean   1.2  0.9   0.1   1.3   2.0  -1.6
# 31                          South America   0.7  0.4  -0.1   1.1   2.0  -1.4
# 32                                 Brazil   1.3  1.1   1.0   1.7   2.3  -1.1
# 33             Mexico and Central America   2.4  2.3   0.5   1.6   1.9  -2.0
# 34                              Caribbean  -0.2  1.6   1.2   5.7   3.4  -0.8
# 35              Least developed countries   4.5  4.6   4.9   5.1   5.4  -0.1
# 37                           World traded   5.7  3.9   0.3   2.3   3.2  -3.4
# 38  World output growth with PPP weightse   3.8  3.6   2.9   3.2   3.4  -0.7
#
# 2   2020
# 3   -0.5
# 4   -0.4
# 5   -0.3
# 6   -0.3
# 7   -0.4
# 8   -0.4
# 9   -0.2
# 10  -0.5
# 11  -0.4
# 12  -0.3
# 13  -0.3
# 14  -0.3
# 16  -0.3
# 17  -0.6
# 18  -0.5
# 19   0.0
# 20  -0.5
# 21  -0.9
# 22  -0.2
# 23  -1.7
# 24  -0.4
# 25  -0.2
# 26  -0.2
# 27  -1.0
# 28  -0.8
# 29  -1.0
# 30  -1.0
# 31  -1.2
# 32  -0.8
# 33  -0.7
# 34   3.7
# 35  -0.6
# 37  -1.6
# 38  -0.5

# %%
wesp_2020.columns
# Out:
# Index(['Annual percentage change', '2017', '2018', '2019a', '2020b', '2021b',
#        '2019', '2020'],
#       dtype='object', name=2)

# %%
wesp_2020.loc[:,['2017', '2018', '2019a', '2020b', '2021b',
       '2019', '2020']] = wesp_2020.loc[:,['2017', '2018', '2019a', '2020b', '2021b',
       '2019', '2020']].apply(pd.to_numeric)

# %%
#wesp_2020["2017"] = wesp_2020['2017'].astype(float)
wesp_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 3 to 38
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Annual percentage change  36 non-null     object
#  1   2017                      34 non-null     float64
#  2   2018                      34 non-null     float64
#  3   2019a                     34 non-null     float64
#  4   2020b                     34 non-null     float64
#  5   2021b                     34 non-null     float64
#  6   2019                      34 non-null     float64
#  7   2020                      34 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 2.4+ KB
